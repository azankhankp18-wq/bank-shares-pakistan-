# %%
# Project 1: Developer and Project Information

print("====================================")
print("        PROJECT INFORMATION         ")
print("====================================")

print("\nDeveloper Information")
print("----------------------")
print("Name      : Azan Akhunzada")
print("Role      : AI Student")

print("\nproject information")
print("----------------------")
print("project   : developer information display")
print("language  : Python")
print("purpose   : to display information about the developer and the project.")
print("version   : 1.000")

print("\nThank you for using this program!")
# Out:
# ...
#         PROJECT INFORMATION
# ...
#
# Developer Information
# ----------------------
# Name      : Azan Akhunzada
# Role      : AI Student
#
# Project Information
# ----------------------
# project   : developer Information Display
# language  : Python
# purpose   : to display information about the developer and the project.
# version   : 1.000
#
# Thank you for using this program!

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print("Sum =", num1 + num2)
print("Difference =", num1 - num2)
print("Product =", num1 * num2)
print("Quotient =", num1 / num2)
# Out:
# Enter first number:  134
# Enter second number:  134
# Sum = 268
# Difference = 0
# Product = 17956
# Quotient = 1.0

# %%
# Out:
# Patient Name:  azan
# Weight (kg):  89
# Height (m):  7.8
# Symptom:  bmi
# Patient: azan
# BMI: 1.46
# Medicine: Doctor se milo
