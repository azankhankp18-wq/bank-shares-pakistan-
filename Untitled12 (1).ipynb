# %%
name = input("Enter patine name: ")
weight = float(input(("Enter you weight: kg ")))
height = float(input(("Enter you height:" )))
a = str(input("Enter you masla:"))
b = input("You check your BP : ")
c = str(input("check your stress: "))

print()
print(f"when your {masla} app loo pendol")
print(f {masla} ke liya  ")

if a<b:
    print("Your BP is too high")
elif a>b:
    print("You BP is much more high")

else:
    print("your BP is normal")

if c<b:
    print("Your stress is normal")

elif c<b:
    print("Your stress is too high")

else:
    ("Chill raho")
# Out:
# Enter patine name:  azan
# Enter you weight: kg  98
# Enter you height: 80
# Enter you masla: sar dar
# You check your BP :  90
# check your stress:  89
# when your sar dard app loo pendol
# agar wis pendol sa be nahi chala to app hosptial chalo sar dard ke liya
# You bp is much more high
# You stress is normal
