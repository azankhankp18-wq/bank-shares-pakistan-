# %%
import speech_recognition as sr
import pyttsx3
import webbrowser
import datetime
import pyjokes

# Voice
engine = pyttsx3.init()

def speak(text):
    print("Jarvis:", text)
    engine.say(text)
    engine.runAndWait()

def listen():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.adjust_for_ambient_noise(source)
        audio = r.listen(source)

    try:
        command = r.recognize_google(audio).lower()
        print("You:", command)
        return command
    except:
        return ""

speak("Hello! I am Jarvis.")

while True:
    command = listen()

    if "youtube" in command:
        speak("Opening YouTube")
        webbrowser.open("https://youtube.com")

    elif "instagram" in command:
        speak("Opening Instagram")
        webbrowser.open("https://instagram.com")

    elif "facebook" in command:
        speak("Opening Facebook")
        webbrowser.open("https://facebook.com")

    elif "google" in command:
        speak("Opening Google")
        webbrowser.open("https://google.com")

    elif "time" in command:
        current_time = datetime.datetime.now().strftime("%I:%M %p")
        speak(f"The time is {current_time}")

    elif "joke" in command:
        joke = pyjokes.get_joke()
        speak(joke)

    elif "search" in command:
        speak("What should I search?")
        query = listen()
        webbrowser.open(f"https://www.google.com/search?q={query}")

    elif "exit" in command or "stop" in command:
        speak("Goodbye!")
        break

    elif command != "":
        speak("Sorry, I don't understand that.")
# Out:
# Jarvis: Hello! I am Jarvis.
# Listening...
# You: open youtube
# Jarvis: Opening YouTube
# Listening...
# Listening...
# Listening...
# Listening...
# You: open youtube and search about
# Jarvis: Opening YouTube
# Listening...
# Listening...
# Listening...
# You: upload
# Jarvis: Sorry, I don't understand that.
# Listening...
# Listening...
# You: song video
# Jarvis: Sorry, I don't understand that.
# Listening...
# Listening...
# You: who is the first chief justice
# Jarvis: Sorry, I don't understand that.
# Listening...
# Listening...
# You: who is the first
# Jarvis: Sorry, I don't understand that.
# Listening...
# Listening...
# Listening...
